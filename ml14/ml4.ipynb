# %%
import pandas as pd
import requests

# %%
response = requests.get(
    'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1'
)

data = response.json()
print("Total Results:", data['total_results'])
# Out:
# Total Results: 10750

# %%
df = pd.DataFrame(data['results'])[
    ['id','title','overview','release_date','popularity','vote_average','vote_count']
]

df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     53.1676
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     36.3000
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     26.6297
# 3  The true story of how businessman Oskar Schind...   1993-12-15     23.9618
# 4  The defense and the prosecution have rested an...   1957-04-10     18.2003
#
#    vote_average  vote_count
# 0         8.718       30056
# 1         8.700       22701
# 2         8.572       13749
# 3         8.567       17277
# 4         8.558        9869

# %%
df = pd.DataFrame()

# %%
for i in range(1, 10):  # keep small for faster output (instead of 429)
    response = requests.get(
        f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}'
    )

    temp_df = pd.DataFrame(response.json()['results'])[
        ['id','title','overview','release_date','popularity','vote_average','vote_count']
    ]

    df = pd.concat([df, temp_df], ignore_index=True)

df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     53.1676
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     36.3000
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     26.6297
# 3  The true story of how businessman Oskar Schind...   1993-12-15     23.9618
# 4  The defense and the prosecution have rested an...   1957-04-10     18.2003
#
#    vote_average  vote_count
# 0         8.718       30056
# 1         8.700       22701
# 2         8.572       13749
# 3         8.567       17277
# 4         8.558        9869

# %%
df
# Out:
#          id                                       title  \
# 0       278                    The Shawshank Redemption
# 1       238                               The Godfather
# 2       240                       The Godfather Part II
# 3       424                            Schindler's List
# 4       389                                12 Angry Men
# ..      ...                                         ...
# 175     422                                          8½
# 176  146233                                   Prisoners
# 177   38288  “The Shorts” by Aldo, Giovanni and Giacomo
# 178  531428                  Portrait of a Lady on Fire
# 179   46738                                   Incendies
#
#                                               overview release_date  \
# 0    Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2    In the continuing saga of the Corleone crime f...   1974-12-20
# 3    The true story of how businessman Oskar Schind...   1993-12-15
# 4    The defense and the prosecution have rested an...   1957-04-10
# ..                                                 ...          ...
# 175  Guido Anselmi, a film director, finds himself ...   1963-02-14
# 176  Keller Dover is facing every parent’s worst ni...   2013-09-19
# 177  I Corti ("Shorts") by Aldo, Giovanni & Giacomo...   1996-03-29
# 178  On an isolated island in Brittany at the end o...   2019-09-06
# 179  A mother's last wishes send twins Jeanne and S...   2010-09-17
#
#      popularity  vote_average  vote_count
# 0       53.1676         8.718       30056
# 1       36.3000         8.700       22701
# 2       26.6297         8.572       13749
# 3       23.9618         8.567       17277
# 4       18.2003         8.558        9869
# ..          ...           ...         ...
# 175      4.6802         8.100        2501
# 176     13.5478         8.104       12905
# 177      0.3823         8.100         359
# 178      7.3620         8.101        2890
# 179      7.5243         8.101        3211
#
# [180 rows x 7 columns]

# %%
df.shape
# Out:
# (180, 7)

# %%
df.to_csv('movies.csv')
