# %%
import pandas as pd

# %%
df = pd.read_csv('1962_2006_walmart_store_openings.csv')
df
# Out:
#       storenum OPENDATE date_super  conversion  st  county  \
# 0            1   7/1/62     3/1/97         1.0   5       7
# 1            2   8/1/64     3/1/96         1.0   5       9
# 2            4   8/1/65     3/1/02         1.0   5       7
# 3            8  10/1/67     3/1/93         1.0   5      29
# 4            7  10/1/67        NaN         NaN   5     119
# ...        ...      ...        ...         ...  ..     ...
# 2987      5403  1/27/06    1/27/06         0.0  17      19
# 2988      3347  1/23/06    1/23/06         0.0  12     105
# 2989      5485  1/27/06        NaN         NaN  17      31
# 2990      3425  1/27/06    1/27/06         0.0  48     201
# 2991      5193  1/31/06        NaN         NaN   6      65
#
#                      STREETADDR            STRCITY STRSTATE  ZIPCODE  \
# 0              2110 WEST WALNUT             Rogers       AR    72756
# 1              1417 HWY 62/65 N           Harrison       AR    72601
# ...

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/plotly/datasets/refs/heads/master/311_Animals_short.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#       Unique Key     Created Date     Closed Date Agency  \
# 0       64345465   3/14/2025 1:20             NaN   NYPD
# 1       64349550   3/14/2025 0:44             NaN   NYPD
# 2       64342912   3/14/2025 0:25             NaN   NYPD
# 3       64344236  3/13/2025 23:33             NaN   NYPD
# 4       64344359  3/13/2025 21:52             NaN   DSNY
# ...          ...              ...             ...    ...
# 4964    63587008   1/1/2025 10:07  1/1/2025 10:54   NYPD
# 4965    63586660   1/1/2025 10:00   1/2/2025 4:32   DSNY
# 4966    63593076    1/1/2025 9:55  1/2/2025 13:11   DSNY
# 4967    63589171    1/1/2025 9:33  1/7/2025 10:50   DSNY
# 4968    63594352    1/1/2025 7:52  1/3/2025 12:08   DSNY
#
#                           Agency Name Complaint Type  Descriptor  \
# 0     New York City Police Department   Animal-Abuse   Neglected
# 1     New York City Police Department   Animal-Abuse    Tortured
# 2     New York City Police Department   Animal-Abuse  No Shelter
# ...

# %%
df = pd.read_csv('sample.tsv', sep='\t', skiprows=1, header=None, names=['customer_id','name','age','city','email','total_spent'], usecols=[0, 1, 2, 3, 5, 8])
df
# Out:
#     customer_id            name  age           city                   email  \
# 0          1001      John Smith   28       New York    john.smith@email.com
# 1          1002    Maria Garcia   34    Los Angeles  maria.garcia@email.com
# 2          1003          Li Wei   22        Toronto        li.wei@email.com
# 3          1004      Aisha Khan   30         London    aisha.khan@email.com
# 4          1005  Robert Johnson   45         Sydney      robert.j@email.com
# 5          1006  Sofia Martinez   26    Mexico City       sofia.m@email.com
# 6          1007       Ahmed Ali   38          Dubai     ahmed.ali@email.com
# 7          1008      Emma Brown   29         Berlin    emma.brown@email.com
# 8          1009        Chen Zhu   31        Beijing      chen.zhu@email.com
# 9          1010    Olivia Davis   27          Tokyo      olivia.d@email.com
# 10         1011  William Wilson   50          Paris     william.w@email.com
# ...

# %%
pd.read_csv('1962_2006_walmart_store_openings.csv',index_col='storenum')
# Out:
#          OPENDATE date_super  conversion  st  county  \
# storenum
# 1          7/1/62     3/1/97         1.0   5       7
# 2          8/1/64     3/1/96         1.0   5       9
# 4          8/1/65     3/1/02         1.0   5       7
# 8         10/1/67     3/1/93         1.0   5      29
# 7         10/1/67        NaN         NaN   5     119
# ...           ...        ...         ...  ..     ...
# 5403      1/27/06    1/27/06         0.0  17      19
# 3347      1/23/06    1/23/06         0.0  12     105
# 5485      1/27/06        NaN         NaN  17      31
# 3425      1/27/06    1/27/06         0.0  48     201
# 5193      1/31/06        NaN         NaN   6      65
#
#                          STREETADDR            STRCITY STRSTATE  ZIPCODE  \
# storenum
# 1                  2110 WEST WALNUT             Rogers       AR    72756
# 2                  1417 HWY 62/65 N           Harrison       AR    72601
# 4                 2901 HWY 412 EAST     Siloam Springs       AR    72761
# ...

# %%
pd.read_csv('1962_2006_walmart_store_openings.csv',header=0)
# Out:
#       storenum OPENDATE date_super  conversion  st  county  \
# 0            1   7/1/62     3/1/97         1.0   5       7
# 1            2   8/1/64     3/1/96         1.0   5       9
# 2            4   8/1/65     3/1/02         1.0   5       7
# 3            8  10/1/67     3/1/93         1.0   5      29
# 4            7  10/1/67        NaN         NaN   5     119
# ...        ...      ...        ...         ...  ..     ...
# 2987      5403  1/27/06    1/27/06         0.0  17      19
# 2988      3347  1/23/06    1/23/06         0.0  12     105
# 2989      5485  1/27/06        NaN         NaN  17      31
# 2990      3425  1/27/06    1/27/06         0.0  48     201
# 2991      5193  1/31/06        NaN         NaN   6      65
#
#                      STREETADDR            STRCITY STRSTATE  ZIPCODE  \
# 0              2110 WEST WALNUT             Rogers       AR    72756
# 1              1417 HWY 62/65 N           Harrison       AR    72601
# ...

# %%
pd.read_csv('1962_2006_walmart_store_openings.csv', usecols=['storenum', 'OPENDATE', 'STRCITY'])
# Out:
#       storenum OPENDATE            STRCITY
# 0            1   7/1/62             Rogers
# 1            2   8/1/64           Harrison
# 2            4   8/1/65     Siloam Springs
# 3            8  10/1/67          Morrilton
# 4            7  10/1/67  North Little Rock
# ...        ...      ...                ...
# 2987      5403  1/27/06             Urbana
# 2988      3347  1/23/06       Winter Haven
# 2989      5485  1/27/06     Evergreen Park
# 2990      3425  1/27/06            Houston
# 2991      5193  1/31/06      Moreno Valley
#
# [2992 rows x 3 columns]

# %%
pd.read_csv('1962_2006_walmart_store_openings.csv', usecols=['STRSTATE']).squeeze()
# Out:
# 0       AR
# 1       AR
# 2       AR
# 3       AR
# 4       AR
#         ..
# 2987    IL
# 2988    FL
# 2989    IL
# 2990    TX
# 2991    CA
# Name: STRSTATE, Length: 2992, dtype: object

# %%
pd.read_csv('1962_2006_walmart_store_openings.csv', nrows=100)
# Out:
#     storenum OPENDATE date_super  conversion  st  county  \
# 0          1   7/1/62     3/1/97         1.0   5       7
# 1          2   8/1/64     3/1/96         1.0   5       9
# 2          4   8/1/65     3/1/02         1.0   5       7
# 3          8  10/1/67     3/1/93         1.0   5      29
# 4          7  10/1/67        NaN         NaN   5     119
# ..       ...      ...        ...         ...  ..     ...
# 95       102   9/1/74     3/1/95         1.0   5       1
# 96       129   7/1/75     3/1/94         1.0  40      19
# 97        98   2/1/75        NaN         NaN  22      67
# 98       103   8/1/75    8/25/04         1.0  40     125
# 99       108   2/1/75        NaN         NaN  40      83
#
#                     STREETADDR            STRCITY STRSTATE  ZIPCODE  \
# 0             2110 WEST WALNUT             Rogers       AR    72756
# 1             1417 HWY 62/65 N           Harrison       AR    72601
# 2            2901 HWY 412 EAST     Siloam Springs       AR    72761
# ...

# %%
df = pd.read_csv('zomato (1).csv',encoding='latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
pd.read_csv('zomato (1).csv', encoding="latin-1",on_bad_lines='skip')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df = pd.read_csv('aug_train.csv',dtype={'target':int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# ...

# %%
df = pd.read_csv('aug_train.csv',dtype={'target':int})
display(df.head())
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
pd.read_csv('IPL Matches 2008-2020.csv',converters={'team2':rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
pd.read_csv('aug_train.csv',na_values=['Male',])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.isnull().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
dfs = pd.read_csv('aug_train.csv',chunksize=5000)
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
